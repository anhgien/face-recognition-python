# %%
import numpy as np
import cv2
import os
import shutil
import glob
import dlib
import imutils
from imutils.face_utils import FaceAligner

# %%
def detectFace(face):
    (h, w) = face.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(face, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB=False, crop=False)
    detector.setInput(blob)
    detections = detector.forward()
    i = np.argmax(detections[0, 0, :, 2])

    confidence = detections[0, 0, i, 2]
    if confidence < args["confidence"]:
        return None

    box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
    (startX, startY, endX, endY) = box.astype("int")

    (fH, fW) = [endY - startY, endX - startX]

    if fH < 20 or fW < 20:
        return None

    return [startX, startY, endX, endY]

def faceToVec(face_aligned):
    
    faceBlob = cv2.dnn.blobFromImage(face_aligned, 1.0 / 255,
				(96, 96), (0, 0, 0), swapRB=True, crop=False)
    net.setInput(faceBlob)
    vec = net.forward()

    return vec

# %%
detector = cv2.dnn.readNetFromCaffe("models/deploy.prototxt", "models/res10_300x300_ssd_iter_140000_fp16.caffemodel")
net = cv2.dnn.readNetFromTorch("models/openface.nn4.small2.v1.t7")
args = {
    "confidence": 0.5
}
pose_predictor=dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")
face_aligner = FaceAligner(pose_predictor)
files = glob.glob(os.path.sep.join(["dataset","*/*"]))
output = "dataset-crop"
embeddings = []
names = []

shutil.rmtree(output)
os.mkdir(output)

for f in files:
    print("[INFO] File {}".format(f))
    img = cv2.imread(f)
    if img is None:
        continue
    img = imutils.resize(img, width=600)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    rect = detectFace(img)
    if rect is None:
        continue

    face_aligned = face_aligner.align(img, gray , dlib.rectangle(*rect))
    vec = faceToVec(face_aligned)
    embeddings.append(vec.flatten())
    label = f.split(os.path.sep)[-2]
    names.append(label)

    fileName = f.split(os.path.sep)[-1]
    dirPath = os.path.sep.join([output, label])

    print("[INFO] Dir {}".format(dirPath))
    if not os.path.exists(dirPath):
        os.mkdir(dirPath)

    dest = os.path.sep.join([dirPath, fileName])
    print(["[INFO] Dest {}".format(dest)])
    cv2.imwrite(dest, face_aligned)

embeddings = np.array(embeddings)
names = np.array(names)
print("names: {}".format(names))
np.save('face_embedding.npy', embeddings)
np.save('labels.npy', names)
print("Done")
# Out:
# [INFO] File dataset/midu/midu-8.jpg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-8.jpg']
# [INFO] File dataset/midu/midu-1.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-1.jpeg']
# [INFO] File dataset/midu/midu-7.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-7.jpeg']
# [INFO] File dataset/midu/midu-5.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-5.jpeg']
# [INFO] File dataset/midu/midu-9.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-9.jpeg']
# [INFO] File dataset/midu/midu-4.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-4.jpeg']
# [INFO] File dataset/midu/midu-10.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-10.jpeg']
# [INFO] File dataset/midu/midu-3.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-3.jpeg']
# [INFO] File dataset/midu/midu-2.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-2.jpeg']
# [INFO] File dataset/midu/midu-11.jpeg
# [INFO] Dir dataset-crop/midu
# ['[INFO] Dest dataset-crop/midu/midu-11.jpeg']
# [INFO] File dataset/rose/rose-1.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-1.jpeg']
# [INFO] File dataset/rose/rose-11.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-11.jpeg']
# [INFO] File dataset/rose/rose-10.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-10.jpeg']
# [INFO] File dataset/rose/rose-6.png
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-6.png']
# [INFO] File dataset/rose/rose-7.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-7.jpeg']
# [INFO] File dataset/rose/rose-6.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-6.jpeg']
# [INFO] File dataset/rose/rose-9.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-9.jpeg']
# [INFO] File dataset/rose/rose-5.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-5.jpeg']
# [INFO] File dataset/rose/rose-4.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-4.jpeg']
# [INFO] File dataset/rose/rose-8.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-8.jpeg']
# [INFO] File dataset/rose/rose-3.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-3.jpeg']
# [INFO] File dataset/rose/rose-2.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-2.jpeg']
# [INFO] File dataset/rose/rose-12.jpeg
# [INFO] Dir dataset-crop/rose
# ['[INFO] Dest dataset-crop/rose/rose-12.jpeg']
# [INFO] File dataset/gien/00018.jpg
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00018.jpg']
# [INFO] File dataset/gien/00008.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00008.png']
# [INFO] File dataset/gien/00009.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00009.png']
# [INFO] File dataset/gien/00010.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00010.png']
# [INFO] File dataset/gien/00004.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00004.png']
# [INFO] File dataset/gien/00005.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00005.png']
# [INFO] File dataset/gien/00011.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00011.png']
# [INFO] File dataset/gien/00007.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00007.png']
# [INFO] File dataset/gien/00013.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00013.png']
# [INFO] File dataset/gien/00012.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00012.png']
# [INFO] File dataset/gien/00006.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00006.png']
# [INFO] File dataset/gien/00002.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00002.png']
# [INFO] File dataset/gien/00016.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00016.png']
# [INFO] File dataset/gien/00017.jpg
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00017.jpg']
# [INFO] File dataset/gien/00003.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00003.png']
# [INFO] File dataset/gien/00015.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00015.png']
# [INFO] File dataset/gien/00001.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00001.png']
# [INFO] File dataset/gien/00000.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00000.png']
# [INFO] File dataset/gien/00014.png
# [INFO] Dir dataset-crop/gien
# ['[INFO] Dest dataset-crop/gien/00014.png']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-35bd065e61e0> in <module>
#      45 embeddings = np.array(embeddings)
#      46 names = np.array(names)
# ---> 47 print("names: {}".formt(names))
#      48 np.save('face_embedding.npy', embeddings)
#      49 np.save('labels.npy', names)
#
# AttributeError: 'str' object has no attribute 'formt'
